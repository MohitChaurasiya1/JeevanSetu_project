# %% [markdown]
# # Jupyter Notebook Starter Placeholder
# This notebook will contain future data exploration and model training logic.

# %%
import pickle
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

train = pd.read_csv("../data/processed/train.csv")
test = pd.read_csv("../data/processed/test.csv")

X_train, y_train = train.drop("Outcome", axis=1), train["Outcome"]
X_test, y_test = test.drop("Outcome", axis=1), test["Outcome"]
print("Train:", X_train.shape, "| Test:", X_test.shape)
# Out:
# Train: (614, 8) | Test: (154, 8)

# %%
# Build and train the Random Forest model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict on the test set and measure accuracy
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", round(accuracy * 100, 2), "%")
# Out:
# Model Accuracy: 86.36 %

# %%
# Saved with a different name so the live model.pkl is not overwritten
with open("../models/model_notebook.pkl", "wb") as f:
    pickle.dump(model, f)
print("Saved: ../models/model_notebook.pkl")
# Out:
# Saved: ../models/model_notebook.pkl
